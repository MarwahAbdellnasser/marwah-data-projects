# %%
# EduFlex Customer Churn Analysis - Preliminary EDA Notebook
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style='whitegrid', palette='pastel', font_scale=1.1)
df = pd.read_csv('EduFlex_CustomerChurn.csv')
df.head()
